# %% [markdown]
# # Library

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Matriz de confusion

# %%
# Matriz de confusión en porcentaje (según la imagen y los datos que enviaste)
cm_percent = np.array([
    [95.37, 1.92, 1.85, 0.76, 0.11],
    [0.70, 97.25, 1.66, 0.30, 0.08],
    [0.24, 0.96, 97.89, 0.69, 0.22],
    [0.53, 0.69, 2.67, 95.75, 0.36],
    [0.35, 1.22, 3.04, 1.30, 94.09]
])

# Etiquetas de clase
labels = ['C', 'MC', 'MF', 'F', 'HF']

# Crear el heatmap
plt.figure(figsize=(7, 5))
sns.heatmap(cm_percent, annot=True, fmt=".2f", cmap="Blues", xticklabels=labels, yticklabels=labels)
plt.xlabel("Predicted")
plt.ylabel("Measure classification")
plt.title("Confusion matrix (%) - Random Forest Model")
plt.tight_layout()
plt.show()

# %%
cm_percent = np.array([
    [94.75, 1.98, 2.17, 0.81, 0.29],
    [0.59, 97.36, 1.44, 0.51, 0.1],
    [0.36, 1.11, 97.59, 0.6, 0.33],
    [0.58, 0.61, 2.24, 96.3, 0.27],
    [0.59, 0.59, 3.39, 1.1, 94.32]
])

# Etiquetas de clase
labels = ['C', 'MC', 'MF', 'F', 'HF']

# Crear el heatmap
plt.figure(figsize=(7, 5))
sns.heatmap(cm_percent, annot=True, fmt=".2f", cmap="Blues", xticklabels=labels, yticklabels=labels)
plt.xlabel("Predicted")
plt.ylabel("Measure classification")
plt.title("Confusion Matrix (%) - XGBoost Model")
plt.tight_layout()
plt.show()

# %%
cm_percent_rf = np.array([
    [95.37, 1.92, 1.85, 0.76, 0.11],
    [0.70, 97.25, 1.66, 0.30, 0.08],
    [0.24, 0.96, 97.89, 0.69, 0.22],
    [0.53, 0.69, 2.67, 95.75, 0.36],
    [0.35, 1.22, 3.04, 1.30, 94.09]
])

# Datos para la Figura 2
cm_percent_xgb = np.array([
    [94.75, 1.98, 2.17, 0.81, 0.29],
    [0.59, 97.36, 1.44, 0.51, 0.1],
    [0.36, 1.11, 97.59, 0.6, 0.33],
    [0.58, 0.61, 2.24, 96.3, 0.27],
    [0.59, 0.59, 3.39, 1.1, 94.32]
])

# Etiquetas de clase
labels = ['C', 'MC', 'MF', 'F', 'HF']

# Crear los subgráficos
fig, axes = plt.subplots(1, 2, figsize=(10.5, 5))

# Figura 1: Random Forest
sns.heatmap(cm_percent_rf, annot=True, fmt=".2f", cmap="Blues", xticklabels=labels, yticklabels=labels, ax=axes[0])
axes[0].set_xlabel("Predicted", fontsize=12.5)
axes[0].set_ylabel("Measure classification", fontsize=12.5)
axes[0].set_title("(a) Confusion Matrix (%) - Random Forest Model", fontsize=15)

# Figura 2: XGBoost
sns.heatmap(cm_percent_xgb, annot=True, fmt=".2f", cmap="Blues", xticklabels=labels, yticklabels=labels, ax=axes[1])
axes[1].set_xlabel("Predicted", fontsize=12.5)
axes[1].set_ylabel("Measure classification", fontsize=12.5)
axes[1].set_title("(b) Confusion Matrix (%) - XGBoost Model", fontsize=15)

# Ajustar el diseño y mostrar la figura
plt.tight_layout()

# Exportar el gráfico como archivo PDF
output_path = r'C:\Users\User\Documents\Code_JRO\1_Fouling_Index\Modelos\confusion_matrices.pdf'
plt.savefig(output_path, format='pdf')

plt.show()

# %%
cm_percent_rf = np.array([
    [95.37, 1.92, 1.85, 0.76, 0.11],
    [0.70, 97.25, 1.66, 0.30, 0.08],
    [0.24, 0.96, 97.89, 0.69, 0.22],
    [0.53, 0.69, 2.67, 95.75, 0.36],
    [0.35, 1.22, 3.04, 1.30, 94.09]
])

# Datos para la Figura 2
cm_percent_xgb = np.array([
    [94.75, 1.98, 2.17, 0.81, 0.29],
    [0.59, 97.36, 1.44, 0.51, 0.1],
    [0.36, 1.11, 97.59, 0.6, 0.33],
    [0.58, 0.61, 2.24, 96.3, 0.27],
    [0.59, 0.59, 3.39, 1.1, 94.32]
])

# Etiquetas de clase
labels = ['C', 'MC', 'MF', 'F', 'HF']

# Crear los subgráficos
fig, axes = plt.subplots(1, 2, figsize=(9, 3.5))

# Figura 1: Random Forest
sns.heatmap(cm_percent_rf, annot=True, fmt=".2f", cmap="Blues", xticklabels=labels, yticklabels=labels, ax=axes[0])
axes[0].set_xlabel("Predicted")
axes[0].set_ylabel("Measure classification")
axes[0].set_title("(a) Confusion Matrix (%) - Random Forest Model")

# Figura 2: XGBoost
sns.heatmap(cm_percent_xgb, annot=True, fmt=".2f", cmap="Blues", xticklabels=labels, yticklabels=labels, ax=axes[1])
axes[1].set_xlabel("Predicted")
axes[1].set_ylabel("Measure classification")
axes[1].set_title("(b) Confusion Matrix (%) - XGBoost Model")

# Ajustar el diseño y mostrar la figura
plt.tight_layout()

# Exportar el gráfico como archivo PDF
output_path = r'C:\Users\User\Documents\Code_JRO\1_Fouling_Index\Modelos\confusion_matrices.pdf'
plt.savefig(output_path, format='pdf')

plt.show()

# %%
cm_percent_rf = np.array([
    [95.37, 1.92, 1.85, 0.76, 0.11],
    [0.70, 97.25, 1.66, 0.30, 0.08],
    [0.24, 0.96, 97.89, 0.69, 0.22],
    [0.53, 0.69, 2.67, 95.75, 0.36],
    [0.35, 1.22, 3.04, 1.30, 94.09]
])

# Datos para la Figura 2
cm_percent_xgb = np.array([
    [94.75, 1.98, 2.17, 0.81, 0.29],
    [0.59, 97.36, 1.44, 0.51, 0.1],
    [0.36, 1.11, 97.59, 0.6, 0.33],
    [0.58, 0.61, 2.24, 96.3, 0.27],
    [0.59, 0.59, 3.39, 1.1, 94.32]
])

# Etiquetas de clase
labels = ['C', 'MC', 'MF', 'F', 'HF']

# Crear los subgráficos
fig, axes = plt.subplots(1, 2, figsize=(9, 3.3))

# Figura 1: Random Forest
sns.heatmap(cm_percent_rf, annot=True, fmt=".2f", cmap="Blues", cbar=False, xticklabels=labels, yticklabels=labels, ax=axes[0])
axes[0].set_xlabel("Predicted")
axes[0].set_ylabel("Measure classification")
axes[0].set_title("(a) Confusion Matrix (%) - Random Forest Model")

# Figura 2: XGBoost
sns.heatmap(cm_percent_xgb, annot=True, fmt=".2f", cmap="Blues", cbar=False, xticklabels=labels, yticklabels=labels, ax=axes[1])
axes[1].set_xlabel("Predicted")
axes[1].set_ylabel("Measure classification")
axes[1].set_title("(b) Confusion Matrix (%) - XGBoost Model")

# Ajustar el diseño y mostrar la figura
plt.tight_layout()

# Exportar el gráfico como archivo PDF
output_path = r'C:\Users\User\Documents\Code_JRO\1_Fouling_Index\Modelos\confusion_matrices.pdf'
plt.savefig(output_path, format='pdf')

plt.show()

# %%
# Etiquetas de clase
labels = ['C', 'MC', 'MF', 'F', 'HF']

# Matrices de confusión en porcentaje
# Random Forest - Accuracy
cm_rf_acc = np.array([
    [95.37, 1.92, 1.85, 0.76, 0.11],
    [0.70, 97.25, 1.66, 0.30, 0.08],
    [0.24, 0.96, 97.89, 0.69, 0.22],
    [0.53, 0.69, 2.67, 95.75, 0.36],
    [0.35, 1.22, 3.04, 1.30, 94.09]
])

# Random Forest - Precision
cm_rf_prec = np.array([
    [95.37, 1.99, 1.77, 0.76, 0.11],
    [0.70, 97.25, 1.69, 0.29, 0.06],
    [0.26, 0.97, 97.88, 0.67, 0.22],
    [0.49, 0.69, 2.64, 95.81, 0.36],
    [0.35, 1.22, 3.04, 1.30, 94.09]
])

# XGBoost - Accuracy
cm_xgb_acc = np.array([
    [94.75, 1.98, 2.17, 0.81, 0.29],
    [0.59, 97.36, 1.44, 0.51, 0.10],
    [0.36, 1.11, 97.59, 0.60, 0.33],
    [0.58, 0.61, 2.24, 96.30, 0.27],
    [0.59, 0.59, 3.39, 1.10, 94.32]
])

# XGBoost - Precision
cm_xgb_prec = np.array([
    [94.21, 2.24, 2.75, 0.69, 0.11],
    [0.67, 96.92, 2.01, 0.32, 0.08],
    [0.26, 1.01, 97.76, 0.73, 0.24],
    [0.46, 0.89, 3.03, 95.25, 0.36],
    [0.35, 1.13, 4.96, 1.30, 92.26]
])

# Crear subplots
fig, axes = plt.subplots(2, 2, figsize=(10.5, 7))

# Gráficos
sns.heatmap(cm_rf_acc, annot=True, fmt=".2f", cmap="Blues", cbar=False, xticklabels=labels, yticklabels=labels, ax=axes[0, 0])
axes[0, 0].set_title("(a) Accuracy - Random Forest", fontsize=14)
axes[0, 0].set_xlabel("Predicted")
axes[0, 0].set_ylabel("True")

sns.heatmap(cm_rf_prec, annot=True, fmt=".2f", cmap="Blues", cbar=False, xticklabels=labels, yticklabels=labels, ax=axes[0, 1])
axes[1, 0].set_title("(b) Precision - Random Forest", fontsize=14)
axes[1, 0].set_xlabel("Predicted")
axes[1, 0].set_ylabel("True")

sns.heatmap(cm_xgb_acc, annot=True, fmt=".2f", cmap="Blues", cbar=False, xticklabels=labels, yticklabels=labels, ax=axes[1, 0])
axes[0, 1].set_title("(c) Accuracy - XGBoost", fontsize=14)
axes[0, 1].set_xlabel("Predicted")
axes[0, 1].set_ylabel("True")

sns.heatmap(cm_xgb_prec, annot=True, fmt=".2f", cmap="Blues", cbar=False, xticklabels=labels, yticklabels=labels, ax=axes[1, 1])
axes[1, 1].set_title("(d) Precision - XGBoost", fontsize=14)
axes[1, 1].set_xlabel("Predicted")
axes[1, 1].set_ylabel("True")

# Ajustar el diseño
plt.tight_layout()

# # Guardar como PDF
# output_path = r'C:\Users\User\Documents\Code_JRO\1_Fouling_Index\Modelos\confusion_matrices_all.pdf'
# plt.savefig(output_path, format='pdf')

plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Leer archivos Excel
path_xgb = r'C:\Users\User\Documents\Code_JRO\1_Fouling_Index\Modelos\XGBoost.xlsx'
path_rf = r'C:\Users\User\Documents\Code_JRO\1_Fouling_Index\Modelos\RandomForest.xlsx'

df_xgb = pd.read_excel(path_xgb)
df_rf = pd.read_excel(path_rf)

# Etiquetas
labels = ['C', 'MC', 'MF', 'F', 'HF']

# Matrices (las mismas que ya teníamos)
cm_rf_acc = np.array([
    [95.37, 1.92, 1.85, 0.76, 0.11],
    [0.70, 97.25, 1.66, 0.30, 0.08],
    [0.24, 0.96, 97.89, 0.69, 0.22],
    [0.53, 0.69, 2.67, 95.75, 0.36],
    [0.35, 1.22, 3.04, 1.30, 94.09]
])
cm_rf_prec = np.array([
    [95.37, 1.99, 1.77, 0.76, 0.11],
    [0.70, 97.25, 1.69, 0.29, 0.06],
    [0.26, 0.97, 97.88, 0.67, 0.22],
    [0.49, 0.69, 2.64, 95.81, 0.36],
    [0.35, 1.22, 3.04, 1.30, 94.09]
])
cm_xgb_acc = np.array([
    [94.75, 1.98, 2.17, 0.81, 0.29],
    [0.59, 97.36, 1.44, 0.51, 0.10],
    [0.36, 1.11, 97.59, 0.60, 0.33],
    [0.58, 0.61, 2.24, 96.30, 0.27],
    [0.59, 0.59, 3.39, 1.10, 94.32]
])
cm_xgb_prec = np.array([
    [94.21, 2.24, 2.75, 0.69, 0.11],
    [0.67, 96.92, 2.01, 0.32, 0.08],
    [0.26, 1.01, 97.76, 0.73, 0.24],
    [0.46, 0.89, 3.03, 95.25, 0.36],
    [0.35, 1.13, 4.96, 1.30, 92.26]
])

# Crear figura con 3 filas y 2 columnas
fig, axes = plt.subplots(3, 2, figsize=(12, 14))

# --------- Heatmaps ----------
sns.heatmap(cm_rf_acc, annot=True, fmt=".2f", cmap="Blues", xticklabels=labels, yticklabels=labels, ax=axes[0, 0])
axes[0, 0].set_title("(a) Accuracy - Random Forest")
axes[0, 0].set_xlabel("Predicted")
axes[0, 0].set_ylabel("True")

sns.heatmap(cm_rf_prec, annot=True, fmt=".2f", cmap="Blues", xticklabels=labels, yticklabels=labels, ax=axes[0, 1])
axes[0, 1].set_title("(b) Precision - Random Forest")
axes[0, 1].set_xlabel("Predicted")
axes[0, 1].set_ylabel("True")

sns.heatmap(cm_xgb_acc, annot=True, fmt=".2f", cmap="Blues", xticklabels=labels, yticklabels=labels, ax=axes[1, 0])
axes[1, 0].set_title("(c) Accuracy - XGBoost")
axes[1, 0].set_xlabel("Predicted")
axes[1, 0].set_ylabel("True")

sns.heatmap(cm_xgb_prec, annot=True, fmt=".2f", cmap="Blues", xticklabels=labels, yticklabels=labels, ax=axes[1, 1])
axes[1, 1].set_title("(d) Precision - XGBoost")
axes[1, 1].set_xlabel("Predicted")
axes[1, 1].set_ylabel("True")

# --------- Scatter Plots ----------
# Random Forest
axes[2, 0].scatter(df_rf["Trial"], df_rf["Accuracy"], label="Accuracy", color="steelblue", marker='o')
axes[2, 0].scatter(df_rf["Trial"], df_rf["Precision"], label="Precision", color="darkorange", marker='x')
axes[2, 0].set_title("(e) RF - Accuracy & Precision over Trials")
axes[2, 0].set_xlabel("Trial")
axes[2, 0].set_ylabel("Score (%)")
axes[2, 0].legend()

# XGBoost
axes[2, 1].scatter(df_xgb["Trial"], df_xgb["Accuracy"], label="Accuracy", color="steelblue", marker='o')
axes[2, 1].scatter(df_xgb["Trial"], df_xgb["Precision"], label="Precision", color="darkorange", marker='x')
axes[2, 1].set_title("(f) XGB - Accuracy & Precision over Trials")
axes[2, 1].set_xlabel("Trial")
axes[2, 1].set_ylabel("Score (%)")
axes[2, 1].legend()

# Ajustar diseño
plt.tight_layout()

# Guardar figura
# output_path = r'C:\Users\User\Documents\Code_JRO\1_Fouling_Index\Modelos\confusion_matrices_with_scatter.pdf'
# plt.savefig(output_path, format='pdf')

plt.show()

# %%
# Leer archivos Excel
path_xgb = r'C:\Users\User\Documents\Code_JRO\1_Fouling_Index\Modelos\XGBoost.xlsx'
path_rf = r'C:\Users\User\Documents\Code_JRO\1_Fouling_Index\Modelos\RandomForest.xlsx'

df_xgb = pd.read_excel(path_xgb)
df_rf = pd.read_excel(path_rf)

# Etiquetas
labels = ['C', 'MC', 'MF', 'F', 'HF']

# Matrices (las mismas que ya teníamos)
cm_rf_acc = np.array([
    [95.37, 1.92, 1.85, 0.76, 0.11],
    [0.70, 97.25, 1.66, 0.30, 0.08],
    [0.24, 0.96, 97.89, 0.69, 0.22],
    [0.53, 0.69, 2.67, 95.75, 0.36],
    [0.35, 1.22, 3.04, 1.30, 94.09]
])
cm_rf_prec = np.array([
    [95.37, 1.99, 1.77, 0.76, 0.11],
    [0.70, 97.25, 1.69, 0.29, 0.06],
    [0.26, 0.97, 97.88, 0.67, 0.22],
    [0.49, 0.69, 2.64, 95.81, 0.36],
    [0.35, 1.22, 3.04, 1.30, 94.09]
])
cm_xgb_acc = np.array([
    [94.75, 1.98, 2.17, 0.81, 0.29],
    [0.59, 97.36, 1.44, 0.51, 0.10],
    [0.36, 1.11, 97.59, 0.60, 0.33],
    [0.58, 0.61, 2.24, 96.30, 0.27],
    [0.59, 0.59, 3.39, 1.10, 94.32]
])
cm_xgb_prec = np.array([
    [94.21, 2.24, 2.75, 0.69, 0.11],
    [0.67, 96.92, 2.01, 0.32, 0.08],
    [0.26, 1.01, 97.76, 0.73, 0.24],
    [0.46, 0.89, 3.03, 95.25, 0.36],
    [0.35, 1.13, 4.96, 1.30, 92.26]
])

# Crear figura con 3 filas y 2 columnas
fig, axes = plt.subplots(3, 2, figsize=(10.5, 11))

# --------- Heatmaps ----------
sns.heatmap(cm_rf_acc, annot=True, fmt=".2f", cmap="Blues", cbar = False, xticklabels=labels, yticklabels=labels, ax=axes[0, 0])
axes[0, 0].set_title("(a) Accuracy - Random Forest", fontsize=14)
axes[0, 0].set_xlabel("Predicted")
axes[0, 0].set_ylabel("Measure classification")

sns.heatmap(cm_rf_prec, annot=True, fmt=".2f", cmap="Blues", cbar = False, xticklabels=labels, yticklabels=labels, ax=axes[0, 1])
axes[0, 1].set_title("(b) Precision - Random Forest", fontsize=14)
axes[0, 1].set_xlabel("Predicted")
axes[0, 1].set_ylabel("Measure classification")

sns.heatmap(cm_xgb_acc, annot=True, fmt=".2f", cmap="Blues", cbar = False, xticklabels=labels, yticklabels=labels, ax=axes[1, 0])
axes[1, 0].set_title("(c) Accuracy - XGBoost", fontsize=14)
axes[1, 0].set_xlabel("Predicted")
axes[1, 0].set_ylabel("Measure classification")

sns.heatmap(cm_xgb_prec, annot=True, fmt=".2f", cmap="Blues", cbar = False, xticklabels=labels, yticklabels=labels, ax=axes[1, 1])
axes[1, 1].set_title("(d) Precision - XGBoost", fontsize=14)
axes[1, 1].set_xlabel("Predicted")
axes[1, 1].set_ylabel("Measure classification")

# --------- Scatter Plots ----------
# Random Forest
axes[2, 0].scatter(df_rf["Trial"], df_rf["Accuracy"], label="Accuracy", color="steelblue", marker='o')
axes[2, 0].scatter(df_rf["Trial"], df_rf["Precision"], label="Precision", color="darkorange", marker='x')
axes[2, 0].set_title("(e) RF - Accuracy & Precision over Trials", fontsize=14)
axes[2, 0].set_xlabel("Trial")
axes[2, 0].set_ylabel("Score (%)")
axes[2, 0].legend()

# XGBoost
axes[2, 1].scatter(df_xgb["Trial"], df_xgb["Accuracy"], label="Accuracy", color="steelblue", marker='o')
axes[2, 1].scatter(df_xgb["Trial"], df_xgb["Precision"], label="Precision", color="darkorange", marker='x')
axes[2, 1].set_title("(f) XGB - Accuracy & Precision over Trials", fontsize=14)
axes[2, 1].set_xlabel("Trial")
axes[2, 1].set_ylabel("Score (%)")
axes[2, 1].legend()

# Ajustar diseño
plt.tight_layout()

# Guardar figura
# output_path = r'C:\Users\User\Documents\Code_JRO\1_Fouling_Index\Modelos\confusion_matrices_with_scatter.pdf'
# plt.savefig(output_path, format='pdf')

plt.show()

# %%
# Leer archivos Excel
path_xgb = r'C:\Users\User\Documents\Code_JRO\1_Fouling_Index\Modelos\XGBoost.xlsx'
path_rf = r'C:\Users\User\Documents\Code_JRO\1_Fouling_Index\Modelos\RandomForest.xlsx'

df_xgb = pd.read_excel(path_xgb)
df_rf = pd.read_excel(path_rf)

# Etiquetas
labels = ['C', 'MC', 'MF', 'F', 'HF']

# Matrices (las mismas que ya teníamos)
cm_rf_acc = np.array([
    [95.37, 1.92, 1.85, 0.76, 0.11],
    [0.70, 97.25, 1.66, 0.30, 0.08],
    [0.24, 0.96, 97.89, 0.69, 0.22],
    [0.53, 0.69, 2.67, 95.75, 0.36],
    [0.35, 1.22, 3.04, 1.30, 94.09]
])
cm_rf_prec = np.array([
    [95.37, 1.99, 1.77, 0.76, 0.11],
    [0.70, 97.25, 1.69, 0.29, 0.06],
    [0.26, 0.97, 97.88, 0.67, 0.22],
    [0.49, 0.69, 2.64, 95.81, 0.36],
    [0.35, 1.22, 3.04, 1.30, 94.09]
])
cm_xgb_acc = np.array([
    [94.75, 1.98, 2.17, 0.81, 0.29],
    [0.59, 97.36, 1.44, 0.51, 0.10],
    [0.36, 1.11, 97.59, 0.60, 0.33],
    [0.58, 0.61, 2.24, 96.30, 0.27],
    [0.59, 0.59, 3.39, 1.10, 94.32]
])
cm_xgb_prec = np.array([
    [94.21, 2.24, 2.75, 0.69, 0.11],
    [0.67, 96.92, 2.01, 0.32, 0.08],
    [0.26, 1.01, 97.76, 0.73, 0.24],
    [0.46, 0.89, 3.03, 95.25, 0.36],
    [0.35, 1.13, 4.96, 1.30, 92.26]
])

# Crear figura con 3 filas y 2 columnas
fig, axes = plt.subplots(3, 2, figsize=(10.5, 11))

# --------- Heatmaps ----------
sns.heatmap(cm_rf_acc, annot=True, fmt=".2f", cmap="Blues", cbar = False, xticklabels=labels, yticklabels=labels, ax=axes[0, 0])
axes[0, 0].set_title("(a) Accuracy - Random Forest", fontsize=14)
axes[0, 0].set_xlabel("Predicted")
axes[0, 0].set_ylabel("Measure classification")

sns.heatmap(cm_rf_prec, annot=True, fmt=".2f", cmap="Reds", cbar = False, xticklabels=labels, yticklabels=labels, ax=axes[0, 1])
axes[1, 0].set_title("(b) Precision - Random Forest", fontsize=14)
axes[1, 0].set_xlabel("Predicted")
axes[1, 0].set_ylabel("Measure classification")

sns.heatmap(cm_xgb_acc, annot=True, fmt=".2f", cmap="BuGn", cbar = False, xticklabels=labels, yticklabels=labels, ax=axes[1, 0])
axes[0, 1].set_title("(d) Accuracy - XGBoost", fontsize=14)
axes[0, 1].set_xlabel("Predicted")
axes[0, 1].set_ylabel("Measure classification")

sns.heatmap(cm_xgb_prec, annot=True, fmt=".2f", cmap="Purples", cbar = False, xticklabels=labels, yticklabels=labels, ax=axes[1, 1])
axes[1, 1].set_title("(e) Precision - XGBoost", fontsize=14)
axes[1, 1].set_xlabel("Predicted")
axes[1, 1].set_ylabel("Measure classification")

# --------- Scatter Plots ----------
# Random Forest
axes[2, 0].scatter(df_rf["Trial"], df_rf["Accuracy"], label="Accuracy", color="blue", marker='o')
axes[2, 0].scatter(df_rf["Trial"], df_rf["Precision"], label="Precision", color="green", marker='x')
axes[2, 0].set_title("(c) RF - Accuracy & Precision over Trials", fontsize=14)
axes[2, 0].set_xlabel("Trial")
axes[2, 0].set_ylabel("Score (%)")
axes[2, 0].set_ylim(0.5, 1)
axes[2, 0].set_xlim(0, 45)
axes[2, 0].legend()

# XGBoost
axes[2, 1].scatter(df_xgb["Trial"], df_xgb["Accuracy"], label="Accuracy", color="red", marker='s')
axes[2, 1].scatter(df_xgb["Trial"], df_xgb["Precision"], label="Precision", color="purple", marker='*')
axes[2, 1].set_title("(f) XGB - Accuracy & Precision over Trials", fontsize=14)
axes[2, 1].set_xlabel("Trial")
axes[2, 1].set_ylabel("Score (%)")
axes[2, 1].set_ylim(0.5, 1)
axes[2, 1].set_xlim(0, 45)
axes[2, 1].legend()

# Ajustar diseño
plt.tight_layout()

# Ajustar espacio entre filas y columnas manualmente
plt.subplots_adjust(hspace=0.4, wspace=0.2)

# Guardar figura
output_path = r'C:\Users\User\Documents\Code_JRO\1_Fouling_Index\Modelos\confusion_matrices_with_scatter_2.pdf'
plt.savefig(output_path, format='pdf')

plt.show()
